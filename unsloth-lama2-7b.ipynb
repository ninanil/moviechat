# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + support us if you can!
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).

# %%
# def install_kaggle():
#   !mamba install --force-reinstall aiohttp -y
#   !pip install -U "xformers<0.0.26" --index-url https://download.pytorch.org/whl/cu121
#   !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git"

#   # Temporary fix for https://github.com/huggingface/datasets/issues/6753
#   !pip install datasets==2.16.0 fsspec==2023.10.0 gcsfs==2023.10.0

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (24.0)
# Collecting pip
#   Downloading pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-24.2

# %%
# !pip install pip3-autoremove
# !pip-autoremove torch torchvision torchaudio -y
# !pip install unsloth
# !pip install wandb
# !pip install dvc
# Out:
# Collecting pip3-autoremove
#   Downloading pip3_autoremove-1.2.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (from pip3-autoremove) (24.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from pip3-autoremove) (70.0.0)
# Downloading pip3_autoremove-1.2.2-py2.py3-none-any.whl (6.7 kB)
# Installing collected packages: pip3-autoremove
# Successfully installed pip3-autoremove-1.2.2
# dill 0.3.8 is installed but dill<0.3.2,>=0.3.1.1 is required
# Redoing requirement with just package name...
# cloudpickle 3.0.0 is installed but cloudpickle~=2.2.1 is required
# Redoing requirement with just package name...
# numpy 1.26.4 is installed but numpy<1.25.0,>=1.14.3 is required
# Redoing requirement with just package name...
# pyarrow 16.1.0 is installed but pyarrow<10.0.0,>=3.0.0 is required
# Redoing requirement with just package name...
# jupyterlab 4.2.4 is installed but jupyterlab~=3.6.0 is required
# Redoing requirement with just package name...
# google-cloud-bigquery 2.34.4 is installed but google-cloud-bigquery[bqstorage,pandas]>=3.10.0 is required
# Redoing requirement with just package name...
# google-cloud-storage 1.44.0 is installed but google-cloud-storage>=2.0.0 is required
# Redoing requirement with just package name...
# pandas 2.2.2 is installed but pandas<2.1.4,>=1.5.0 is required
# Redoing requirement with just package name...
# botocore 1.34.131 is installed but botocore<1.30.0,>=1.29.100 is required
# Redoing requirement with just package name...
# google-api-python-client 2.141.0 is installed but google-api-python-client==1.8.0 is required
# Redoing requirement with just package name...
# packaging 21.3 is installed but packaging>=23.0 is required
# Redoing requirement with just package name...
# The 'cubinlinker' distribution was not found and is required by the application
# Skipping cubinlinker
# cuda-python 12.6.0 is installed but cuda-python<12.0a0,>=11.7.1 is required
# Redoing requirement with just package name...
# The 'cupy-cuda11x>=12.0.0' distribution was not found and is required by the application
# Skipping cupy-cuda11x
# The 'ptxcompiler' distribution was not found and is required by the application
# Skipping ptxcompiler
# The 'cupy-cuda11x>=12.0.0' distribution was not found and is required by the application
# Skipping cupy-cuda11x
# The 'cupy-cuda11x>=12.0.0' distribution was not found and is required by the application
# Skipping cupy-cuda11x
# pydantic 2.8.2 is installed but pydantic~=1.10.0 is required
# Redoing requirement with just package name...
# dask 2024.8.1 is installed but dask==2024.7.1 is required
# Redoing requirement with just package name...
# The 'google.auth>=1.14.1' distribution was not found and is required by the application
# Skipping google.auth
# scipy 1.14.0 is installed but scipy<1.14.0,>=1.7.0 is required
# Redoing requirement with just package name...
# google-api-core 2.11.1 is installed but google-api-core[grpc]<2.0.0dev,>=1.22.2 is required
# Redoing requirement with just package name...
# google-api-core 2.11.1 is installed but google-api-core[grpc]<2.0.0dev,>=1.14.0 is required
# Redoing requirement with just package name...
# pyarrow 16.1.0 is installed but pyarrow<15,>=2 is required
# Redoing requirement with just package name...
# jupyter-lsp 1.5.1 is installed but jupyter-lsp>=2.0.0 is required
# Redoing requirement with just package name...
# jupyter-lsp 1.5.1 is installed but jupyter-lsp>=2.0.0 is required
# Redoing requirement with just package name...
# google-cloud-storage 1.44.0 is installed but google-cloud-storage<3,>=2.2.1 is required
# Redoing requirement with just package name...
# packaging 21.3 is installed but packaging>=22 is required
# Redoing requirement with just package name...
# Shapely 1.8.5.post1 is installed but shapely>=2.0.1 is required
# Redoing requirement with just package name...
# Shapely 1.8.5.post1 is installed but shapely>=2 is required
# Redoing requirement with just package name...
# Shapely 1.8.5.post1 is installed but shapely<2.1,>=2.0 is required
# Redoing requirement with just package name...
# Shapely 1.8.5.post1 is installed but shapely>=2 is required
# Redoing requirement with just package name...
# packaging 21.3 is installed but packaging>=23.2 is required
# Redoing requirement with just package name...
# dask 2024.8.1 is installed but dask==2024.7.1 is required
# Redoing requirement with just package name...
# cuda-python 12.6.0 is installed but cuda-python<12.0a0,>=11.7.1 is required
# Redoing requirement with just package name...
# Shapely 1.8.5.post1 is installed but shapely>=2.0.1 is required
# Redoing requirement with just package name...
# Shapely 1.8.5.post1 is installed but shapely>=2.0.1 is required
# Redoing requirement with just package name...
# nltk 3.2.4 is installed but nltk>=3.8 is required
# Redoing requirement with just package name...
# The 'libucx>=1.15.0' distribution was not found and is required by the application
# Skipping libucx
# packaging 21.3 is installed but packaging>=23.1 is required
# Redoing requirement with just package name...
# scipy 1.14.0 is installed but scipy<1.14,>=1.4.1 is required
# Redoing requirement with just package name...
# torch 2.4.0 (/opt/conda/lib/python3.10/site-packages)
# torchaudio 2.4.0 (/opt/conda/lib/python3.10/site-packages)
#     torch 2.4.0 (/opt/conda/lib/python3.10/site-packages)
# torchvision 0.19.0 (/opt/conda/lib/python3.10/site-packages)
#     torch 2.4.0 (/opt/conda/lib/python3.10/site-packages)
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Collecting unsloth
#   Downloading unsloth-2024.10.2-py3-none-any.whl.metadata (56 kB)
# Collecting unsloth-zoo (from unsloth)
#   Downloading unsloth_zoo-2024.10.2-py3-none-any.whl.metadata (48 kB)
# Collecting torch>=2.4.0 (from unsloth)
#   Downloading torch-2.5.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.28.post1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from unsloth) (21.3)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.8.12-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: transformers<4.45.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (4.44.0)
# Requirement already satisfied: datasets>=2.16.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (2.21.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from unsloth) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from unsloth) (5.9.3)
# Requirement already satisfied: wheel>=0.42.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (0.43.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from unsloth) (1.26.4)
# Collecting accelerate>=0.34.1 (from unsloth)
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.11.1,>=0.7.9 (from unsloth)
#   Downloading trl-0.11.1-py3-none-any.whl.metadata (12 kB)
# Collecting peft!=0.11.0,>=0.7.1 (from unsloth)
#   Downloading peft-0.13.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: protobuf<4.0.0 in /opt/conda/lib/python3.10/site-packages (from unsloth) (3.20.3)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from unsloth) (0.24.6)
# Collecting hf-transfer (from unsloth)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth) (0.4.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.15.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.16.0->unsloth) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.9.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->unsloth) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->unsloth) (3.1.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting sympy==1.13.1 (from torch>=2.4.0->unsloth)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<4.45.0->unsloth) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers<4.45.0->unsloth) (0.19.1)
# Requirement already satisfied: docstring-parser>=0.16 in /opt/conda/lib/python3.10/site-packages (from tyro->unsloth) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro->unsloth) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting torch>=2.4.0 (from unsloth)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (1.13.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12 (from nvidia-cudnn-cu12==9.1.0.70->torch>=2.4.0->unsloth)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12 (from nvidia-cusolver-cu12==11.6.1.9->torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.4.0->unsloth)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting transformers<4.45.0 (from unsloth)
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.4.0->unsloth) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Downloading unsloth-2024.10.2-py3-none-any.whl (163 kB)
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
# Downloading peft-0.13.2-py3-none-any.whl (320 kB)
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 51.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 133.5 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 107.9 MB/s eta 0:00:00
# Downloading trl-0.11.1-py3-none-any.whl (318 kB)
# Downloading tyro-0.8.12-py3-none-any.whl (108 kB)
# Downloading xformers-0.0.28.post1-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 108.9 MB/s eta 0:00:00
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 26.6 MB/s eta 0:00:0000:0100:01
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 41.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 74.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 108.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 129.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 32.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 104.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 111.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 105.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 101.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 105.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 67.7 MB/s eta 0:00:0000:0100:01
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 87.7 MB/s eta 0:00:00
# Downloading unsloth_zoo-2024.10.2-py3-none-any.whl (39 kB)
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 100.2 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Installing collected packages: triton, sympy, shtab, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, hf-transfer, nvidia-cusparse-cu12, nvidia-cudnn-cu12, tyro, nvidia-cusolver-cu12, transformers, torch, xformers, bitsandbytes, accelerate, trl, peft, unsloth-zoo, unsloth
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.0
#     Uninstalling transformers-4.44.0:
#       Successfully uninstalled transformers-4.44.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.33.0
#     Uninstalling accelerate-0.33.0:
#       Successfully uninstalled accelerate-0.33.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.7.1 requires torchvision>=0.5, which is not installed.
# fastai 2.7.16 requires torchvision>=0.11, which is not installed.
# timm 1.0.8 requires torchvision, which is not installed.
# Successfully installed accelerate-1.0.1 bitsandbytes-0.44.1 hf-transfer-0.1.8 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 peft-0.13.2 shtab-1.7.1 sympy-1.13.1 torch-2.4.1 transformers-4.44.2 triton-3.0.0 trl-0.11.1 tyro-0.8.12 unsloth-2024.10.2 unsloth-zoo-2024.10.2 xformers-0.0.28.post1
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.17.7)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.13.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.7.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting dvc
#   Downloading dvc-3.55.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from dvc) (23.2.0)
# Collecting celery (from dvc)
#   Downloading celery-5.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: colorama>=0.3.9 in /opt/conda/lib/python3.10/site-packages (from dvc) (0.4.6)
# Collecting configobj>=5.0.6 (from dvc)
#   Downloading configobj-5.0.9.tar.gz (101 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: distro>=1.3 in /opt/conda/lib/python3.10/site-packages (from dvc) (1.9.0)
# Collecting dpath<3,>=2.1.0 (from dvc)
#   Downloading dpath-2.2.0-py3-none-any.whl.metadata (15 kB)
# Collecting dulwich (from dvc)
#   Downloading dulwich-0.22.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting dvc-data<3.17,>=3.16.2 (from dvc)
#   Downloading dvc_data-3.16.6-py3-none-any.whl.metadata (5.1 kB)
# Collecting dvc-http>=2.29.0 (from dvc)
#   Downloading dvc_http-2.32.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting dvc-objects (from dvc)
#   Downloading dvc_objects-5.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting dvc-render<2,>=1.0.1 (from dvc)
#   Downloading dvc_render-1.0.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dvc-studio-client<1,>=0.21 (from dvc)
#   Downloading dvc_studio_client-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting dvc-task<1,>=0.3.0 (from dvc)
#   Downloading dvc_task-0.40.2-py3-none-any.whl.metadata (10.0 kB)
# Collecting flatten-dict<1,>=0.4.1 (from dvc)
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting flufl.lock<9,>=8.1.0 (from dvc)
#   Downloading flufl_lock-8.1.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: fsspec>=2024.2.0 in /opt/conda/lib/python3.10/site-packages (from dvc) (2024.6.1)
# Requirement already satisfied: funcy>=1.14 in /opt/conda/lib/python3.10/site-packages (from dvc) (2.0)
# Collecting grandalf<1,>=0.7 (from dvc)
#   Downloading grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting gto<2,>=1.6.0 (from dvc)
#   Downloading gto-1.7.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting hydra-core>=1.1 (from dvc)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting iterative-telemetry>=0.0.7 (from dvc)
#   Downloading iterative_telemetry-0.0.9-py3-none-any.whl.metadata (4.1 kB)
# Collecting kombu (from dvc)
#   Downloading kombu-5.4.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: networkx>=2.5 in /opt/conda/lib/python3.10/site-packages (from dvc) (3.3)
# Collecting omegaconf (from dvc)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging>=19 in /opt/conda/lib/python3.10/site-packages (from dvc) (21.3)
# Collecting pathspec>=0.10.3 (from dvc)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in /opt/conda/lib/python3.10/site-packages (from dvc) (3.11.0)
# Requirement already satisfied: psutil>=5.8 in /opt/conda/lib/python3.10/site-packages (from dvc) (5.9.3)
# Requirement already satisfied: pydot>=1.2.4 in /opt/conda/lib/python3.10/site-packages (from dvc) (1.4.2)
# Collecting pygtrie>=2.3.2 (from dvc)
#   Downloading pygtrie-2.5.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pyparsing>=2.4.7 in /opt/conda/lib/python3.10/site-packages (from dvc) (3.1.2)
# Requirement already satisfied: requests>=2.22 in /opt/conda/lib/python3.10/site-packages (from dvc) (2.32.3)
# Requirement already satisfied: rich>=12 in /opt/conda/lib/python3.10/site-packages (from dvc) (13.7.1)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /opt/conda/lib/python3.10/site-packages (from dvc) (0.18.6)
# Collecting scmrepo<4,>=3.3.4 (from dvc)
#   Downloading scmrepo-3.3.8-py3-none-any.whl.metadata (4.8 kB)
# Collecting shortuuid>=0.5 (from dvc)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: shtab<2,>=1.3.4 in /opt/conda/lib/python3.10/site-packages (from dvc) (1.7.1)
# Requirement already satisfied: tabulate>=0.8.7 in /opt/conda/lib/python3.10/site-packages (from dvc) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from dvc) (0.13.2)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /opt/conda/lib/python3.10/site-packages (from dvc) (4.66.4)
# Collecting voluptuous>=0.11.7 (from dvc)
#   Downloading voluptuous-0.15.2-py3-none-any.whl.metadata (20 kB)
# Collecting zc.lockfile>=1.2.1 (from dvc)
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl.metadata (6.2 kB)
# Collecting dictdiffer>=0.8.1 (from dvc-data<3.17,>=3.16.2->dvc)
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting diskcache>=5.2.1 (from dvc-data<3.17,>=3.16.2->dvc)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting sqltrie<1,>=0.11.0 (from dvc-data<3.17,>=3.16.2->dvc)
#   Downloading sqltrie-0.11.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: orjson<4,>=3 in /opt/conda/lib/python3.10/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (3.10.4)
# Collecting aiohttp-retry>=2.5.0 (from dvc-http>=2.29.0->dvc)
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# Collecting billiard<5.0,>=4.2.0 (from celery->dvc)
#   Downloading billiard-4.2.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting vine<6.0,>=5.1.0 (from celery->dvc)
#   Downloading vine-5.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0,>=8.1.2 in /opt/conda/lib/python3.10/site-packages (from celery->dvc) (8.1.7)
# Collecting click-didyoumean>=0.3.0 (from celery->dvc)
#   Downloading click_didyoumean-0.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting click-repl>=0.2.0 (from celery->dvc)
#   Downloading click_repl-0.3.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: click-plugins>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from celery->dvc) (1.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from celery->dvc) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from celery->dvc) (2.9.0.post0)
# Requirement already satisfied: six<2.0,>=1.12 in /opt/conda/lib/python3.10/site-packages (from flatten-dict<1,>=0.4.1->dvc) (1.16.0)
# Requirement already satisfied: atpublic in /opt/conda/lib/python3.10/site-packages (from flufl.lock<9,>=8.1.0->dvc) (4.1.0)
# Requirement already satisfied: typer>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from gto<2,>=1.6.0->dvc) (0.12.3)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from gto<2,>=1.6.0->dvc) (2.8.2)
# Requirement already satisfied: semver>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from gto<2,>=1.6.0->dvc) (3.0.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from gto<2,>=1.6.0->dvc) (0.4)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->dvc)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: appdirs in /opt/conda/lib/python3.10/site-packages (from iterative-telemetry>=0.0.7->dvc) (1.4.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from iterative-telemetry>=0.0.7->dvc) (3.15.1)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu->dvc)
#   Downloading amqp-5.2.0-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: PyYAML>=5.1.0 in /opt/conda/lib/python3.10/site-packages (from omegaconf->dvc) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.22->dvc) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.22->dvc) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.22->dvc) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.22->dvc) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=12->dvc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=12->dvc) (2.18.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.10/site-packages (from ruamel.yaml>=0.17.11->dvc) (0.2.8)
# Requirement already satisfied: gitpython>3 in /opt/conda/lib/python3.10/site-packages (from scmrepo<4,>=3.3.4->dvc) (3.1.43)
# Collecting pygit2>=1.14.0 (from scmrepo<4,>=3.3.4->dvc)
#   Downloading pygit2-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting asyncssh<3,>=2.13.1 (from scmrepo<4,>=3.3.4->dvc)
#   Downloading asyncssh-2.17.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from zc.lockfile>=1.2.1->dvc) (70.0.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (3.9.5)
# Requirement already satisfied: cryptography>=39.0 in /opt/conda/lib/python3.10/site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.3.4->dvc) (42.0.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.3.4->dvc) (4.12.2)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /opt/conda/lib/python3.10/site-packages (from click-repl>=0.2.0->celery->dvc) (3.0.47)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>3->scmrepo<4,>=3.3.4->dvc) (4.0.11)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc) (0.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc) (2.20.1)
# Collecting cffi>=1.17.0 (from pygit2>=1.14.0->scmrepo<4,>=3.3.4->dvc)
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc) (1.5.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc) (4.0.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.17.0->pygit2>=1.14.0->scmrepo<4,>=3.3.4->dvc) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.3.4->dvc) (5.0.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc) (0.2.13)
# Downloading dvc-3.55.2-py3-none-any.whl (455 kB)
# Downloading dpath-2.2.0-py3-none-any.whl (17 kB)
# Downloading dvc_data-3.16.6-py3-none-any.whl (77 kB)
# Downloading dvc_http-2.32.0-py3-none-any.whl (12 kB)
# Downloading dvc_objects-5.1.0-py3-none-any.whl (33 kB)
# Downloading dvc_render-1.0.2-py3-none-any.whl (22 kB)
# Downloading dvc_studio_client-0.21.0-py3-none-any.whl (16 kB)
# Downloading dvc_task-0.40.2-py3-none-any.whl (21 kB)
# Downloading celery-5.4.0-py3-none-any.whl (425 kB)
# Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Downloading flufl_lock-8.1.0-py3-none-any.whl (11 kB)
# Downloading grandalf-0.8-py3-none-any.whl (41 kB)
# Downloading gto-1.7.1-py3-none-any.whl (46 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Downloading iterative_telemetry-0.0.9-py3-none-any.whl (10 kB)
# Downloading kombu-5.4.2-py3-none-any.whl (201 kB)
# Downloading vine-5.1.0-py3-none-any.whl (9.6 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pygtrie-2.5.0-py3-none-any.whl (25 kB)
# Downloading scmrepo-3.3.8-py3-none-any.whl (73 kB)
# Downloading dulwich-0.22.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (968 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 968.1/968.1 kB 37.5 MB/s eta 0:00:00
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Downloading voluptuous-0.15.2-py3-none-any.whl (31 kB)
# Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Downloading amqp-5.2.0-py3-none-any.whl (50 kB)
# Downloading asyncssh-2.17.0-py3-none-any.whl (363 kB)
# Downloading billiard-4.2.1-py3-none-any.whl (86 kB)
# Downloading click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Downloading click_repl-0.3.0-py3-none-any.whl (10 kB)
# Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
# Downloading pygit2-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 84.4 MB/s eta 0:00:00
# Downloading sqltrie-0.11.1-py3-none-any.whl (17 kB)
# Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
# Building wheels for collected packages: configobj, antlr4-python3-runtime
#   Building wheel for configobj (pyproject.toml) ... done
#   Created wheel for configobj: filename=configobj-5.0.9-py2.py3-none-any.whl size=35615 sha256=c464a24cfa6d1d335e37d38b1028c7e8b409c6329f5eef07b4fa4108d92fc545
#   Stored in directory: /root/.cache/pip/wheels/a1/6c/03/6c5e3cf1a6e4b9e2fc5c4409be4abc5a8268bd9c878739cb32
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=bab60a7ac92bc0d2787b58642d46f0b69cdda7007fb478c0aae4d75677649ca6
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built configobj antlr4-python3-runtime
# Installing collected packages: pygtrie, dictdiffer, antlr4-python3-runtime, zc.lockfile, voluptuous, vine, sqltrie, shortuuid, pathspec, omegaconf, grandalf, flufl.lock, flatten-dict, dvc-render, dvc-objects, dulwich, dpath, diskcache, configobj, click-didyoumean, cffi, billiard, pygit2, iterative-telemetry, hydra-core, dvc-studio-client, dvc-data, click-repl, amqp, kombu, asyncssh, aiohttp-retry, scmrepo, dvc-http, celery, gto, dvc-task, dvc
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.16.0
#     Uninstalling cffi-1.16.0:
#       Successfully uninstalled cffi-1.16.0
# Successfully installed aiohttp-retry-2.8.3 amqp-5.2.0 antlr4-python3-runtime-4.9.3 asyncssh-2.17.0 billiard-4.2.1 celery-5.4.0 cffi-1.17.1 click-didyoumean-0.3.1 click-repl-0.3.0 configobj-5.0.9 dictdiffer-0.9.0 diskcache-5.6.3 dpath-2.2.0 dulwich-0.22.3 dvc-3.55.2 dvc-data-3.16.6 dvc-http-2.32.0 dvc-objects-5.1.0 dvc-render-1.0.2 dvc-studio-client-0.21.0 dvc-task-0.40.2 flatten-dict-0.4.2 flufl.lock-8.1.0 grandalf-0.8 gto-1.7.1 hydra-core-1.3.2 iterative-telemetry-0.0.9 kombu-5.4.2 omegaconf-2.3.0 pathspec-0.12.1 pygit2-1.16.0 pygtrie-2.5.0 scmrepo-3.3.8 shortuuid-1.0.13 sqltrie-0.11.1 vine-5.1.0 voluptuous-0.15.2 zc.lockfile-3.0.post1

# %%
# !pip install boto3 --upgrade
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.10/site-packages (1.26.100)
# Collecting boto3
#   Downloading boto3-1.35.44-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.36.0,>=1.35.44 (from boto3)
#   Downloading botocore-1.35.44-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.44->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.44->boto3) (1.26.18)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.44->boto3) (1.16.0)
# Downloading boto3-1.35.44-py3-none-any.whl (139 kB)
# Downloading botocore-1.35.44-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 122.3 MB/s eta 0:00:00
# Downloading s3transfer-0.10.3-py3-none-any.whl (82 kB)
# Installing collected packages: botocore, s3transfer, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.131
#     Uninstalling botocore-1.34.131:
#       Successfully uninstalled botocore-1.34.131
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.6.2
#     Uninstalling s3transfer-0.6.2:
#       Successfully uninstalled s3transfer-0.6.2
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.26.100
#     Uninstalling boto3-1.26.100:
#       Successfully uninstalled boto3-1.26.100
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.13.2 requires botocore<1.34.132,>=1.34.70, but you have botocore 1.35.44 which is incompatible.
# Successfully installed boto3-1.35.44 botocore-1.35.44 s3transfer-0.10.3

# %%
# Uninstall the problematic packages
# !pip uninstall -y cffi pycparser

# Install compatible versions
# !pip install cffi==1.16.0 pycparser==2.20
# Out:
# Found existing installation: cffi 1.17.1
# Uninstalling cffi-1.17.1:
#   Successfully uninstalled cffi-1.17.1
# Found existing installation: pycparser 2.22
# Uninstalling pycparser-2.22:
#   Successfully uninstalled pycparser-2.22
# Collecting cffi==1.16.0
#   Downloading cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser==2.20
#   Downloading pycparser-2.20-py2.py3-none-any.whl.metadata (907 bytes)
# Downloading cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Installing collected packages: pycparser, cffi
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pygit2 1.16.0 requires cffi>=1.17.0, but you have cffi 1.16.0 which is incompatible.
# Successfully installed cffi-1.16.0 pycparser-2.20

# %%
# !pip install evaluate
# !pip install rouge_score bert_score
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.21.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.24.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from evaluate) (21.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.15.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->evaluate) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from rouge_score) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.4.1)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.44.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.66.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from bert_score) (3.7.5)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from bert_score) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->bert_score) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.0.0->bert_score) (12.4.127)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.24.6)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (9.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=eadf82b0274e2f78f4cee685229d552da7db45003f0356d5173a018ace4c234d
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score, bert_score
# Successfully installed bert_score-0.3.13 rouge_score-0.1.2

# %%
# %%capture
# import torch
# major_version, minor_version = torch.cuda.get_device_capability()
# # Must install separately since Colab has torch 2.2.1, which breaks packages
# # !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# # install_kaggle()
# if major_version >= 8:
#     # Use this for new GPUs like Ampere, Hopper GPUs (RTX 30xx, RTX 40xx, A100, H100, L40)
#     !pip install --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
# else:
#     # Use this for older GPUs (V100, Tesla T4, RTX 20xx)
#     !pip install --no-deps xformers trl peft accelerate bitsandbytes triton
# pass

# %%
# !pyenv install 3.10.15
# !pyenv global 3.10.15

# %%
# !nvidia-smi
# Out:
# Sat Oct 19 00:53:28 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0             26W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from huggingface_hub import login
login('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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import wandb
wandb.login(key = '2e7ba1c4f4eb4c439719e22f2276e30f13c4c7b5')

run = wandb.init(project= 'Moviechat', entity='niloufarcolab6-n')
# run = wandb.init(project= cfg.wandb.project_name, entity=cfg.wandb.entity)
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: niloufarcolab6 (niloufarcolab6-n). Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113656677778434, max=1.0…
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/kaggle/working/wandb/run-20241019_005332-ttth7wxu</code>
# Syncing run <strong><a href='https://wandb.ai/niloufarcolab6-n/Moviechat/runs/ttth7wxu' target="_blank">good-water-101</a></strong> to <a href='https://wandb.ai/niloufarcolab6-n/Moviechat' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/niloufarcolab6-n/Moviechat' target="_blank">https://wandb.ai/niloufarcolab6-n/Moviechat</a>
#  View run at <a href='https://wandb.ai/niloufarcolab6-n/Moviechat/runs/ttth7wxu' target="_blank">https://wandb.ai/niloufarcolab6-n/Moviechat/runs/ttth7wxu</a>
# wandb: Network error resolved after 0:01:13.006827, resuming normal operation.

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
# !pip install mlflow
# !pip install dagshub
# Out:
# Collecting mlflow
#   Downloading mlflow-2.17.0-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==2.17.0 (from mlflow)
#   Downloading mlflow_skinny-2.17.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.13.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (7.1.0)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.6)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.7.5)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (16.1.0)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.0.30)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.1.4)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.17.0->mlflow)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.17.0->mlflow)
#   Downloading databricks_sdk-0.35.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (7.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (1.25.0)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (21.3)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (3.20.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (0.5.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.18)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (1.8.2)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.5-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: google-auth~=2.0 in /opt/conda/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.30.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.0->mlflow) (3.19.2)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (0.46b0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (2024.7.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.6.0)
# Downloading mlflow-2.17.0-py3-none-any.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 116.8 MB/s eta 0:00:0000:01
# Downloading mlflow_skinny-2.17.0-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 98.1 MB/s eta 0:00:00
# Downloading graphene-3.4-py2.py3-none-any.whl (114 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading databricks_sdk-0.35.0-py3-none-any.whl (568 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.4/568.4 kB 21.8 MB/s eta 0:00:00
# Downloading graphql_core-3.2.5-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: graphql-core, cachetools, gunicorn, graphql-relay, graphene, databricks-sdk, mlflow-skinny, mlflow
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.4
#     Uninstalling cachetools-4.2.4:
#       Successfully uninstalled cachetools-4.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.2 requires cubinlinker, which is not installed.
# cudf 24.8.2 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.2 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.2 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.2 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.8.2 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# Successfully installed cachetools-5.3.3 databricks-sdk-0.35.0 graphene-3.4 graphql-core-3.2.5 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-2.17.0 mlflow-skinny-2.17.0
# Collecting dagshub
#   Downloading dagshub-0.3.39-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: PyYAML>=5 in /opt/conda/lib/python3.10/site-packages (from dagshub) (6.0.2)
# Collecting fusepy>=3 (from dagshub)
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.10/site-packages (from dagshub) (1.4.4)
# Requirement already satisfied: click>=8.0.4 in /opt/conda/lib/python3.10/site-packages (from dagshub) (8.1.7)
# Requirement already satisfied: httpx>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from dagshub) (0.27.0)
# Requirement already satisfied: GitPython>=3.1.29 in /opt/conda/lib/python3.10/site-packages (from dagshub) (3.1.43)
# Requirement already satisfied: rich>=13.1.0 in /opt/conda/lib/python3.10/site-packages (from dagshub) (13.7.1)
# Collecting dacite~=1.6.0 (from dagshub)
#   Downloading dacite-1.6.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tenacity>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from dagshub) (8.3.0)
# Collecting gql[requests] (from dagshub)
#   Downloading gql-3.5.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.10/site-packages (from dagshub) (0.6.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from dagshub) (2.2.2)
# Collecting treelib>=1.6.4 (from dagshub)
#   Downloading treelib-1.7.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting pathvalidate>=3.0.0 (from dagshub)
#   Downloading pathvalidate-3.2.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from dagshub) (2.9.0.post0)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.10/site-packages (from dagshub) (1.35.44)
# Collecting dagshub-annotation-converter>=0.1.0 (from dagshub)
#   Downloading dagshub_annotation_converter-0.1.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from dagshub-annotation-converter>=0.1.0->dagshub) (5.3.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from dagshub-annotation-converter>=0.1.0->dagshub) (9.5.0)
# Requirement already satisfied: pydantic>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from dagshub-annotation-converter>=0.1.0->dagshub) (2.8.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from dagshub-annotation-converter>=0.1.0->dagshub) (4.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython>=3.1.29->dagshub) (4.0.11)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->dagshub) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->dagshub) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->dagshub) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->dagshub) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->dagshub) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->dagshub) (0.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=13.1.0->dagshub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=13.1.0->dagshub) (2.18.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from treelib>=1.6.4->dagshub) (1.16.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.44 in /opt/conda/lib/python3.10/site-packages (from boto3->dagshub) (1.35.44)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3->dagshub) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from boto3->dagshub) (0.10.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->dagshub) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->dagshub) (0.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.2 in /opt/conda/lib/python3.10/site-packages (from gql[requests]->dagshub) (3.2.5)
# Requirement already satisfied: yarl<2.0,>=1.6 in /opt/conda/lib/python3.10/site-packages (from gql[requests]->dagshub) (1.9.4)
# Collecting backoff<3.0,>=1.11.1 (from gql[requests]->dagshub)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests<3,>=2.26 in /opt/conda/lib/python3.10/site-packages (from gql[requests]->dagshub) (2.32.3)
# Collecting requests-toolbelt<2,>=1.0.0 (from gql[requests]->dagshub)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->dagshub) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->dagshub) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->dagshub) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx>=0.23.0->dagshub) (1.2.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.44->boto3->dagshub) (1.26.18)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.29->dagshub) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->dagshub) (0.1.2)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->dagshub) (21.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0.0->dagshub-annotation-converter>=0.1.0->dagshub) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0.0->dagshub-annotation-converter>=0.1.0->dagshub) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.26->gql[requests]->dagshub) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub) (1.0.0)
# Requirement already satisfied: multidict>=4.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (6.0.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json->dagshub) (3.1.2)
# Downloading dagshub-0.3.39-py3-none-any.whl (247 kB)
# Downloading dacite-1.6.0-py3-none-any.whl (12 kB)
# Downloading dagshub_annotation_converter-0.1.1-py3-none-any.whl (32 kB)
# Downloading pathvalidate-3.2.1-py3-none-any.whl (23 kB)
# Downloading treelib-1.7.0-py3-none-any.whl (18 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading gql-3.5.0-py2.py3-none-any.whl (74 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py) ... done
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10487 sha256=d9e3df60afb77d5fe9b01690a01621a6e5473f945b62dcf68001a514c20be502
#   Stored in directory: /root/.cache/pip/wheels/c0/18/f6/f0d6be9d0435e2677ce5cc758e91da50053dce456a346f08c5
# Successfully built fusepy
# Installing collected packages: fusepy, treelib, pathvalidate, dacite, backoff, requests-toolbelt, gql, dagshub-annotation-converter, dagshub
#   Attempting uninstall: dacite
#     Found existing installation: dacite 1.8.1
#     Uninstalling dacite-1.8.1:
#       Successfully uninstalled dacite-1.8.1
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 0.10.1
#     Uninstalling requests-toolbelt-0.10.1:
#       Successfully uninstalled requests-toolbelt-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.5.0 requires requests-toolbelt<1,>=0.8.0, but you have requests-toolbelt 1.0.0 which is incompatible.
# ydata-profiling 4.9.0 requires dacite>=1.8, but you have dacite 1.6.0 which is incompatible.
# ydata-profiling 4.9.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.0 which is incompatible.
# Successfully installed backoff-2.2.1 dacite-1.6.0 dagshub-0.3.39 dagshub-annotation-converter-0.1.1 fusepy-3.0.1 gql-3.5.0 pathvalidate-3.2.1 requests-toolbelt-1.0.0 treelib-1.7.0

# %%
import dagshub, mlflow

dagshub.init(repo_owner='ninanildev', repo_name='moviechat', mlflow=True)
mlflow.set_tracking_uri("https://dagshub.com/ninanildev/moviechat.mlflow")
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Output()
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=8d4b4419-9fda-4d8e-820b-a21a904ba7e6&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=cab2a6c3d382702bbbef9191f104ab70834646c733113fcac9252095660950fa
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accessing as ninanildev
# Initialized MLflow to track repo "ninanildev/moviechat"
# Repository ninanildev/moviechat initialized!

# %%
#!pip3 install -U xformers --index-url https://download.pytorch.org/whl/cu124

# %% [markdown]
# * We support Llama, Mistral, CodeLlama, TinyLlama, Vicuna, Open Hermes etc
# * And Yi, Qwen ([llamafied](https://huggingface.co/models?sort=trending&search=qwen+llama)), Deepseek, all Llama, Mistral derived archs.
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * With [PR 26037](https://github.com/huggingface/transformers/pull/26037), we support downloading 4bit models **4x faster**! [Our repo](https://huggingface.co/unsloth) has Llama, Mistral 4bit models.
# * [**NEW**] We make Gemma 6 trillion tokens **2.5x faster**! See our [Gemma notebook](https://colab.research.google.com/drive/10NbwlsRChbma1v55m8LAPYG15uQv6HLo?usp=sharing)

# %%
# !pip install pip3-autoremove
# !pip-autoremove torch torchvision torchaudio -y
# !pip install "torch==2.4.0" "xformers==0.0.27.post2" triton torchvision torchaudio
# !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git"

# %%
#!pip install boto3==1.35.31 botocore==1.35.31

# %%
# !python --version
# Out:
# Python 3.10.14

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024#2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
# fourbit_models = [
#     "unsloth/mistral-7b-bnb-4bit",
#     "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
#     "unsloth/llama-2-7b-bnb-4bit",
#     "unsloth/llama-2-13b-bnb-4bit",
#     "unsloth/codellama-34b-bnb-4bit",
#     "unsloth/tinyllama-bnb-4bit",
#     "unsloth/gemma-7b-bnb-4bit", # New Google 6 trillion tokens model 2.5x faster!
#     "unsloth/gemma-2b-bnb-4bit",
# ] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-2-7b-bnb-4bit", # Choose ANY! eg mistralai/Mistral-7B-Instruct-v0.2
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
#     device_map='auto',  
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# ==((====))==  Unsloth 2024.10.2: Fast Llama patching. Transformers = 4.44.2.
#    \\   /|    GPU: Tesla P100-PCIE-16GB. Max memory: 15.888 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.4.1+cu121. CUDA = 6.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/3.87G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/948 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Unsloth: We fixed a gradient accumulation bug, but it seems like you don't have the latest transformers version!
# Please update transformers via:
# `pip uninstall transformers -y && pip install --upgrade --no-cache-dir "git+https://github.com/huggingface/transformers.git"`

# %%
print(tokenizer)
# Out:
# LlamaTokenizerFast(name_or_path='unsloth/llama-2-7b-bnb-4bit', vocab_size=32000, model_max_length=4096, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.10.2 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `ChatML` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing).
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
EOS_TOKEN = tokenizer.eos_token
def formatting_prompts_func(examples):
#     prompt = """### Instruction:{}
# ### Input:{}
# ### Context:{}
# """
    prompt = """Instruction:{}
Input:{}
Context:{}
"""
    # Extract fields from examples
    instructions = examples["instruction"]
    inputs = examples["input"]
    outputs = examples["response"]  
    contexts = examples["context"]
    split = examples["split"]
    texts = []  # List to store formatted prompts

    # Iterate through the data and format each example
    for instruction, input, context, output in zip(instructions, inputs, contexts, outputs):
        # Initialize the context string
        context_str = ""
        if context and isinstance(context, dict):
            # Extract specific context fields
            movie_name = context.get('movie_name', 'Unknown')
            genre = context.get('genre', 'Unknown')
            year = context.get('year', 'Unknown')
            plot_outline = context.get('plot_outline', 'Unknown')
            context_str += f"Movie: {movie_name}\nGenre: {genre}\nYear: {year}\nPlot Outline: {plot_outline}"
            # Handle NaN values explicitly for plot_outline and other fields
            if isinstance(plot_outline, float) and math.isnan(plot_outline):
                plot_outline = 'Unknown'
            
            # Additional context fields
            if 'character_names' in context:
                character_names = context.get('character_names', 'Unknown')
                context_str += f"Character names: {character_names}\n"
            if 'imdb_rating' in context:
                imdb_rating = context.get('imdb_rating', 'Unknown')
                context_str += f"IMDb rating: {imdb_rating}\n"
            if 'num_imdb_votes' in context:
                num_imdb_votes = context.get('num_imdb_votes', 'Unknown')
                context_str += f"Number of IMDb votes: {num_imdb_votes}\n"
#             if split == 'train':
            text = prompt.format(instruction, input, context_str,'\nResponse:', output) + EOS_TOKEN
#             else:
#                 text = prompt.format(instruction, input, context_str) + EOS_TOKEN
        # Format the prompt with instruction, input, context, and response
        
        texts.append(text)

    # Return the formatted text as a dictionary to be used with map function
    return {"text": texts}

# %%
# dataset_url = 'https://huggingface.co/datasets/niloufarna/MovieChat/resolve/main/dataset/combined_movie_dataset.json'

# %%
artifact = run.use_artifact('niloufarcolab6-n/Moviechat/combined_movie_dataset:v0', type='dataset')
artifact_dir = artifact.download()
# Out:
# wandb: Downloading large artifact combined_movie_dataset:v0, 119.26MB. 1 files...
# wandb:   1 of 1 files downloaded.
# Done. 0:0:2.2

# %%
from datasets import load_dataset

# Load the entire dataset
# dataset = load_dataset('json', data_files=dataset_url)
dataset = load_dataset('json', data_dir=artifact_dir)
# Filter each split based on the 'split' field
train_dataset = dataset['train'].filter(lambda x: x['split'] == 'train')
test_dataset = dataset['train'].filter(lambda x: x['split'] == 'test')
val_dataset = dataset['train'].filter(lambda x: x['split'] == 'val')

# Example usage
print("Train Dataset:", train_dataset)
print("Test Dataset:", test_dataset)
print("Validation Dataset:", val_dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Filter:   0%|          | 0/87495 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/87495 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/87495 [00:00<?, ? examples/s]
# Train Dataset: Dataset({
#     features: ['split', 'type', 'instruction', 'input', 'context', 'response'],
#     num_rows: 61245
# })
# Test Dataset: Dataset({
#     features: ['split', 'type', 'instruction', 'input', 'context', 'response'],
#     num_rows: 26160
# })
# Validation Dataset: Dataset({
#     features: ['split', 'type', 'instruction', 'input', 'context', 'response'],
#     num_rows: 90
# })

# %%
train_dataset = train_dataset.map(formatting_prompts_func, batched = True)
val_dataset = val_dataset.map(formatting_prompts_func, batched = True)
test_dataset = test_dataset.map(formatting_prompts_func, batched = True)
# Out:
# Map:   0%|          | 0/61245 [00:00<?, ? examples/s]
# Map:   0%|          | 0/90 [00:00<?, ? examples/s]
# Map:   0%|          | 0/26160 [00:00<?, ? examples/s]

# %%
val_dataset
# Out:
# Dataset({
#     features: ['split', 'type', 'instruction', 'input', 'context', 'response', 'text'],
#     num_rows: 90
# })

# %%
train_dataset = train_dataset.remove_columns(['split', 'type', 'instruction', 'input', 'context', 'response'])
val_dataset = val_dataset.remove_columns(['split', 'type', 'instruction', 'input', 'context','response'])
test_dataset = test_dataset.remove_columns(['split', 'type', 'instruction', 'input', 'context','response']).to_pandas()

# %%
# import evaluate
# from transformers import TrainerCallback
# class MlflowEvaluationCallback(TrainerCallback):
#     def __init__(self, trainer, val_data, tokenizer, log_interval):
#         self.trainer = trainer
#         self.val_data = val_data
#         self.tokenizer = tokenizer  # Pass the tokenizer to decode token IDs
#         # Initialize the evaluation metrics
#         self.bleu = evaluate.load("bleu")
#         self.rouge = evaluate.load("rouge")
#         self.bertscore = evaluate.load("bertscore")
#         self.log_interval = log_interval


#     def on_step_end(self, args, state, control, **kwargs):
#         if mlflow.active_run() is None:
#             mlflow.start_run()
#         if state.global_step % self.log_interval == 0:
#             try:
#                 # Access the trainer from kwargs
#                 trainer = kwargs['trainer']
#                 model = self.trainer.model

#                 # Log the current epoch
#                 mlflow.log_metric('epoch', state.epoch)

#                 # Define the model URI; adjust based on your tracking setup
#                 model_uri = f"runs:/{mlflow.active_run().info.run_id}/model"


#                 # Perform predictions on the validation set
#                 predictions_output = trainer.predict(self.val_data)

#                 # Extract predictions and ground truth (references)
#                 predictions = predictions_output.predictions
#                 references = predictions_output.label_ids

#                 # Decode predictions and references from token IDs to strings
#                 decoded_predictions = self.tokenizer.batch_decode(predictions, skip_special_tokens=True)
#                 decoded_references = self.tokenizer.batch_decode(references, skip_special_tokens=True)

#                 # Convert references to required format (list of lists for BLEU)
#                 formatted_references = [[ref.strip()] for ref in decoded_references]

#                 # Perform BLEU evaluation
#                 bleu_results = self.bleu.compute(predictions=[pred.strip() for pred in decoded_predictions],
#                                                  references=formatted_references)
#                 rouge_results = self.rouge.compute(predictions=[pred.strip() for pred in decoded_predictions],
#                                                    references=[ref.strip() for ref in decoded_references])
#                 bertscore_results = self.bertscore.compute(predictions=decoded_predictions,
#                                                            references=decoded_references,
#                                                            lang="en")

#                 # Log BLEU, ROUGE, and BERTScore metrics
#                 mlflow.log_metric(f"bleu", bleu_results["bleu"])
#                 for key, value in rouge_results.items():
#                     mlflow.log_metric(f"rouge_{key}", value)
#                 mlflow.log_metric(f"bertscore_precision", sum(bertscore_results["precision"]) / len(bertscore_results["precision"]))
#                 mlflow.log_metric(f"bertscore_recall", sum(bertscore_results["recall"]) / len(bertscore_results["recall"]))
#                 mlflow.log_metric(f"bertscore_f1", sum(bertscore_results["f1"]) / len(bertscore_results["f1"]))

#                 # Optional: add more custom metrics
#                   val_dataset_df = val_data.to_pandas() 
# #                 results = mlflow.evaluate(
# #                     model_uri=model_uri,
# #                     data=val_dataset_df,
# #                     targets="response",
# #                     model_type="text-generation",
# #                     extra_metrics=[
# #                         mlflow.evaluate.metrics.Toxicity(),
# #                         mlflow.evaluate.metrics.Latency(),
# #                         mlflow.evaluate.metrics.AnswerSimilarity(),
# #                     ],
# #                     evaluator_config={
# #                         "metric_prefix": f"epoch_{int(state.epoch)}_",
# #                         "log_model": False,
# #                     },
# #                 )

#                 # Log the custom evaluation metrics
#                 for metric_name, metric_value in results.metrics.items():
#                     mlflow.log_metric(metric_name, metric_value, step=int(state.global_step))

#             except Exception as e:
#                 # Log the exception with mlflow
#                 mlflow.log_param("evaluation_error", str(e))
#                 print(e)
#                 print(f"An error occurred during evaluation at epoch {state.epoch}: {e}")
#         elif state.global_step % (self.log_interval*10) == 0:
#             model = self.trainer.model
#             # Save the model to the MLflow model registry
#             mlflow.pytorch.log_model(model, "model")

# %%
test_dataset
# Out:
#                                                     text
# 0      Instruction:Continue the conversation between ...
# 1      Instruction:Continue the conversation between ...
# 2      Instruction:Continue the conversation between ...
# 3      Instruction:Continue the conversation between ...
# 4      Instruction:Continue the conversation between ...
# ...                                                  ...
# 26155  Instruction:Answer the following question:\nIn...
# 26156  Instruction:Answer the following question:\nIn...
# 26157  Instruction:Answer the following question:\nIn...
# 26158  Instruction:Answer the following question:\nIn...
# 26159  Instruction:Answer the following question:\nIn...
#
# [26160 rows x 1 columns]

# %%
for idx in range(3,6):  # Print a few samples
    sample_text = val_dataset[idx]["text"]
    tokenized_sample = tokenizer(sample_text, truncation=True, max_length=max_seq_length)
    print(f"Original text: {sample_text}")
    print(f"Tokenized input IDs: {tokenized_sample['input_ids']}")
# Out:
# Original text: Instruction:Continue the conversation between the characters.
# Input:Suzette: Madam should sleep.
#  Grusinskaya: I've done my hair differently -- do you like that?
#  Suzette: When a lady falls in love she does her hair differently.
#  Grusinskaya: In the middle of the night -- those flowers make me think of a funeral. Laurels and tube-roses.  Oh, think, Suzette -- the Villa and the sun at Tremezzo -- quiet -- simple -- happy -- we'll have a guest, Suzette.
#  Suzette: Yes, Madam. And now Madam will sleep. It is not long 'till the train.
# Context:Movie: grand hotel
# Genre: drama, romance
# Year: 1932
# Plot Outline: Berlin's plushest, most expensive hotel is the setting where in the words of Dr. Otternschlag "People come, people go. Nothing ever happens.". The doctor is usually drunk so he missed the fact that Baron von Geigern is broke and trying to steal eccentric dancer Grusinskaya's pearls. He ends up stealing her heart instead. Powerful German businessman Preysing brow beats Kringelein, one of his company's lowly bookkeepers but it is the terminally ill Kringelein who holds all the cards in the end. Meanwhile, the Baron also steals the heart of Preysing's mistress, Flaemmchen, but she doesn't end up with either one of them in the end...Character names: Grusinskaya, Suzette
# IMDb rating: 7.7
# Number of IMDb votes: 6088
#
# </s>
# Tokenized input IDs: [1, 2799, 4080, 29901, 1323, 14150, 278, 14983, 1546, 278, 4890, 29889, 13, 4290, 29901, 29903, 3365, 2353, 29901, 4104, 314, 881, 8709, 29889, 13, 1632, 375, 262, 808, 9010, 29901, 306, 29915, 345, 2309, 590, 11315, 17587, 1192, 437, 366, 763, 393, 29973, 13, 2166, 29920, 2353, 29901, 1932, 263, 11379, 20074, 297, 5360, 1183, 947, 902, 11315, 17587, 29889, 13, 1632, 375, 262, 808, 9010, 29901, 512, 278, 7256, 310, 278, 4646, 1192, 1906, 18281, 1207, 592, 1348, 310, 263, 2090, 13537, 29889, 997, 545, 3137, 322, 260, 4003, 29899, 1883, 267, 29889, 29871, 6439, 29892, 1348, 29892, 2166, 29920, 2353, 1192, 278, 14439, 322, 278, 6575, 472, 6479, 21660, 2502, 1192, 11813, 1192, 2560, 1192, 9796, 1192, 591, 29915, 645, 505, 263, 17838, 29892, 2166, 29920, 2353, 29889, 13, 2166, 29920, 2353, 29901, 3869, 29892, 4104, 314, 29889, 1126, 1286, 4104, 314, 674, 8709, 29889, 739, 338, 451, 1472, 525, 29873, 453, 278, 7945, 29889, 13, 2677, 29901, 18749, 29901, 4595, 16730, 13, 15462, 276, 29901, 18621, 29892, 6017, 749, 13, 12883, 29901, 29871, 29896, 29929, 29941, 29906, 13, 20867, 4451, 1220, 29901, 5115, 29915, 29879, 715, 1878, 342, 29892, 1556, 19390, 16730, 338, 278, 4444, 988, 297, 278, 3838, 310, 4942, 29889, 8540, 725, 816, 3110, 376, 15666, 1991, 2041, 29892, 2305, 748, 29889, 9531, 3926, 5930, 1213, 29889, 450, 11619, 338, 5491, 4192, 2960, 577, 540, 13726, 278, 2114, 393, 15991, 1005, 1879, 335, 824, 338, 14455, 322, 1811, 304, 1886, 284, 16882, 296, 2200, 6025, 2265, 1632, 375, 262, 808, 9010, 29915, 29879, 282, 799, 3137, 29889, 940, 10614, 701, 1886, 12818, 902, 5192, 2012, 29889, 9206, 1319, 5332, 5381, 1171, 4721, 952, 292, 3347, 367, 1446, 476, 5393, 6146, 262, 29892, 697, 310, 670, 5001, 29915, 29879, 4482, 368, 3143, 17462, 414, 541, 372, 338, 278, 6624, 635, 4486, 476, 5393, 6146, 262, 1058, 8640, 599, 278, 15889, 297, 278, 1095, 29889, 25065, 29892, 278, 15991, 884, 1886, 1338, 278, 5192, 310, 4721, 952, 292, 29915, 29879, 5862, 1253, 29892, 383, 433, 331, 29885, 2724, 29892, 541, 1183, 1838, 29915, 29873, 1095, 701, 411, 2845, 697, 310, 963, 297, 278, 1095, 856, 20755, 2983, 29901, 1632, 375, 262, 808, 9010, 29892, 2166, 29920, 2353, 13, 29902, 11602, 21700, 29901, 29871, 29955, 29889, 29955, 13, 4557, 310, 11769, 18952, 29901, 29871, 29953, 29900, 29947, 29947, 13, 13, 2]
# Original text: Instruction:Continue the conversation between the characters.
# Input:Clark: I've never been in a place like this before.
# Context:Movie: superman iv: the quest for peace
# Genre: action, adventure, family, fantasy, sci-fi
# Year: 1987
# Plot Outline: Superman does a great deal in his newest adventure. Archnemesis Lex Luthor, determined to make the world safe for nuclear arms merchants, creates a being to challenge the Man of Steel: the radiation-charged Nuclear Man. Luthor steals a strand of Superman's hair from a museum and uses it to create Nuclear Man, a creature that gets energy from the Sun. His purpose is to use him as a weapon to take down the Man of Steel, so that Luthor will be free to realize his criminal plans. The two super-powered enemies clash in an explosive screen extravaganza that sees Superman save the Statue of Liberty, repulse a volcanic eruption of Mount Etna, rebuild the demolished Great Wall of China and perform many more spectacular feats.Character names: Clark, Lacy
# IMDb rating: 3.4
# Number of IMDb votes: 15332
#
# </s>
# Tokenized input IDs: [1, 2799, 4080, 29901, 1323, 14150, 278, 14983, 1546, 278, 4890, 29889, 13, 4290, 29901, 6821, 935, 29901, 306, 29915, 345, 2360, 1063, 297, 263, 2058, 763, 445, 1434, 29889, 13, 2677, 29901, 18749, 29901, 2428, 1171, 20444, 29901, 278, 21126, 363, 10776, 13, 15462, 276, 29901, 3158, 29892, 17623, 545, 29892, 3942, 29892, 13568, 8995, 29892, 4560, 29899, 7241, 13, 12883, 29901, 29871, 29896, 29929, 29947, 29955, 13, 20867, 4451, 1220, 29901, 5670, 1171, 947, 263, 2107, 5376, 297, 670, 716, 342, 17623, 545, 29889, 2595, 15344, 6656, 15045, 365, 329, 2015, 29892, 10087, 304, 1207, 278, 3186, 9109, 363, 20346, 10188, 2778, 305, 1934, 29892, 10017, 263, 1641, 304, 18766, 278, 2315, 310, 2443, 295, 29901, 278, 27310, 29899, 25389, 287, 405, 1682, 1945, 2315, 29889, 365, 329, 2015, 1886, 1338, 263, 851, 392, 310, 5670, 1171, 29915, 29879, 11315, 515, 263, 19133, 322, 3913, 372, 304, 1653, 405, 1682, 1945, 2315, 29892, 263, 23940, 393, 4947, 5864, 515, 278, 8991, 29889, 3600, 6437, 338, 304, 671, 1075, 408, 263, 28639, 304, 2125, 1623, 278, 2315, 310, 2443, 295, 29892, 577, 393, 365, 329, 2015, 674, 367, 3889, 304, 16289, 670, 22161, 13900, 29889, 450, 1023, 2428, 29899, 13519, 287, 22595, 1067, 1161, 297, 385, 20389, 573, 4315, 4805, 29894, 351, 8520, 393, 18553, 5670, 1171, 4078, 278, 6666, 434, 310, 10895, 1017, 29892, 1634, 19994, 263, 1700, 3068, 293, 604, 29884, 683, 310, 8040, 8748, 1056, 29892, 337, 4282, 278, 27745, 3276, 7027, 14406, 310, 7551, 322, 2189, 1784, 901, 6683, 562, 1070, 1238, 1446, 29889, 20755, 2983, 29901, 17129, 29892, 365, 4135, 13, 29902, 11602, 21700, 29901, 29871, 29941, 29889, 29946, 13, 4557, 310, 11769, 18952, 29901, 29871, 29896, 29945, 29941, 29941, 29906, 13, 13, 2]
# Original text: Instruction:Continue the conversation between the characters.
# Input:Morgan: That thunder's sure somethin'.
# Context:Movie: tombstone
# Genre: action, drama, history, romance, western
# Year: 1993
# Plot Outline: After success cleaning up Dodge City, Wyatt Earp moves to Tombstone, Arizona, and wishes to get rich in obscurity. He meets his brothers there, as well as his old friend Doc Holliday. A band of outlaws that call themselves The Cowboys are causing problems in the region with various acts of random violence, and inevitably come into confrontation with Holliday and the Earps, which leads to a shoot-out at the O.K. Corral.Character names: Morgan, Wyatt
# IMDb rating: 7.7
# Number of IMDb votes: 44204
#
# </s>
# Tokenized input IDs: [1, 2799, 4080, 29901, 1323, 14150, 278, 14983, 1546, 278, 4890, 29889, 13, 4290, 29901, 29924, 6388, 29901, 2193, 266, 5062, 29915, 29879, 1854, 1047, 621, 262, 4286, 13, 2677, 29901, 18749, 29901, 20450, 12734, 13, 15462, 276, 29901, 3158, 29892, 18621, 29892, 4955, 29892, 6017, 749, 29892, 15782, 13, 12883, 29901, 29871, 29896, 29929, 29929, 29941, 13, 20867, 4451, 1220, 29901, 2860, 2551, 5941, 292, 701, 360, 17979, 4412, 29892, 10167, 1131, 5290, 29886, 16229, 304, 323, 3424, 12734, 29892, 23716, 29892, 322, 28688, 304, 679, 8261, 297, 19726, 7710, 29889, 940, 28103, 670, 21383, 727, 29892, 408, 1532, 408, 670, 2030, 5121, 28197, 379, 3028, 22394, 29889, 319, 3719, 310, 714, 433, 5652, 393, 1246, 6053, 450, 21638, 833, 952, 526, 10805, 4828, 297, 278, 5120, 411, 5164, 14741, 310, 4036, 21448, 29892, 322, 297, 5750, 277, 2197, 2041, 964, 21751, 362, 411, 379, 3028, 22394, 322, 278, 5290, 567, 29892, 607, 11981, 304, 263, 15049, 29899, 449, 472, 278, 438, 29889, 29968, 29889, 2994, 1705, 29889, 20755, 2983, 29901, 20549, 29892, 10167, 1131, 13, 29902, 11602, 21700, 29901, 29871, 29955, 29889, 29955, 13, 4557, 310, 11769, 18952, 29901, 29871, 29946, 29946, 29906, 29900, 29946, 13, 13, 2]

# %%
# # prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

# # ### Instruction:
# # {}

# # ### Input:
# # {}

# # ### Response:
# # {}"""

# # EOS_TOKEN = tokenizer.eos_token
# # def formatting_prompts_func(examples):
# #     instructions = examples["instruction"]
# #     inputs       = examples["input"]
# #     outputs      = examples["output"]
# #     texts = []
# #     for instruction, input, output in zip(instructions, inputs, outputs):
# #         # Must add EOS_TOKEN, otherwise your generation will go on forever!
# #         text = prompt.format(instruction, input, output) + EOS_TOKEN
# #         texts.append(text)
# #     return { "text" : texts, }
# pass
# import pandas as pd
# from datasets import load_dataset, concatenate_datasets
# # dataset_name = 'niloufarna/MovieChat'
# dataset_url = 'https://huggingface.co/datasets/niloufarna/MovieChat/resolve/main/cornell_movie_data.json'
# dataset_url2 = 'https://huggingface.co/datasets/niloufarna/MovieChat/resolve/main/movieqa_movie_data.json'
# dataset1 = load_dataset('json', data_files = dataset_url, split='train')
# dataset2 = load_dataset('json', data_files = dataset_url2, split='train')
# dataset1 = dataset1.map(formatting_prompts_func, batched = True)
# dataset2 = dataset2.map(formatting_prompts_func, batched = True)
# # concatenate_dataset
# # Define splits while loading if not explicitly defined in the JSON
# # dataset = load_dataset(dataset_name, split='train')
# # print(dataset)  # This will give you an overview of the dataset
# # print(dataset.column_names)  # Check available columns
# # print(dataset['train'][0])
# train_dataset1 = dataset1.filter(lambda x: x['split'] == 'train')
# val_dataset1 = dataset1.filter(lambda x: x['split'] == 'val')
# test_dataset1 = dataset1.filter(lambda x: x['split'] == 'test')

# train_dataset2 = dataset2.filter(lambda x: x['split'] == 'train')
# val_dataset2 = dataset2.filter(lambda x: x['split'] == 'val')
# test_dataset2 = dataset2.filter(lambda x: x['split'] == 'test')


# train_dataset1 = train_dataset1.remove_columns(['split', 'type', 'instruction', 'input', 'context', 'response'])
# train_dataset2 = train_dataset2.remove_columns(['split', 'type', 'instruction', 'input', 'context', 'response'])                         
# train_dataset =  concatenate_datasets([train_dataset1, train_dataset2])

# val_dataset1 = val_dataset1.remove_columns(['split', 'type', 'instruction', 'input', 'context']).to_pandas()
# val_dataset2 = val_dataset2.remove_columns(['split', 'type', 'instruction', 'input', 'context']).to_pandas()                        
# val_dataset =  pd.concat([val_dataset1, val_dataset2], axis = 0)

# test_dataset1 = test_dataset1.remove_columns(['split', 'type', 'instruction', 'input', 'context']).to_pandas()
# test_dataset2 = test_dataset2.remove_columns(['split', 'type', 'instruction', 'input', 'context']).to_pandas()                        
# test_dataset =  pd.concat([test_dataset1, test_dataset2], axis = 0)

# %%
# import evaluate
# import traceback
# from transformers import TrainerCallback
# import mlflow

# class MlflowEvaluationCallback(TrainerCallback):
#     def __init__(self, trainer, val_data, tokenizer, log_interval):
#         self.trainer = trainer
#         self.val_data = val_data
#         self.tokenizer = tokenizer
#         self.bleu = evaluate.load("bleu")
#         self.log_interval = log_interval

#     def on_step_end(self, args, state, control, **kwargs):
#         print("mlflow.active_run()", mlflow.active_run())
#         if mlflow.active_run() is None:
#             mlflow.start_run()
        
#         if state.global_step % self.log_interval == 0:
#             print(" In state.global_step", state.global_step)
#             print("vla_data",len(self.val_data))
#             print("val_data type", type(self.val_data))
#             print("self.val_data len", len(self.val_data))
#             try:
#                 # Access the model
#                 model = self.trainer.model

#                 # Log the current epoch
#                 mlflow.log_metric('my_test_epoch', state.epoch)
#                 print("epoch on_step_end ", state.epoch)
#                 # Perform predictions on the validation set
# #                 predictions_output = self.trainer.predict(self.val_data)

# #                 # Extract predictions and references
# #                 predictions = predictions_output.predictions
# #                 references = predictions_output.label_ids

# #                 # Decode predictions and references from token IDs to strings
# #                 decoded_predictions = self.tokenizer.batch_decode(predictions, skip_special_tokens=True)
# #                 decoded_references = self.tokenizer.batch_decode(references, skip_special_tokens=True)

# #                 # Convert references to required format (list of lists for BLEU)
# #                 formatted_references = [[ref.strip()] for ref in decoded_references]

# #                 # Perform BLEU evaluation
# #                 bleu_results = self.bleu.compute(predictions=[pred.strip() for pred in decoded_predictions],
# #                                                  references=formatted_references)

# #                 # Log BLEU metric
# #                 mlflow.log_metric(f"bleu", bleu_results["bleu"])
# #                 print("bleu on_step_end", bleu_results["bleu"])
#             except Exception as e:
#                 # Log the full traceback to understand the error better
#                 print("In on_step_end exception")
#                 error_message = traceback.format_exc()
#                 mlflow.log_param("evaluation_error", str(e))
#                 print(f"An error occurred during evaluation at epoch {state.epoch}:\n{error_message}")

# # Example usage:
# # trainer = ...
# # tokenizer = ...
# # val_data = ...

# %%
# callback = MlflowEvaluationCallback(trainer, val_data, tokenizer, log_interval=10)
# trainer.add_callback(callback)

# %%
# # Initialize evaluation metrics
# import evaluate
# bleu_metric = evaluate.load("bleu")
# rouge_metric = evaluate.load("rouge")
# bertscore_metric = evaluate.load("bertscore")

# def compute_metrics(eval_preds):
#     predictions, labels = eval_preds
    
#     # Move predictions and labels to CPU
#     predictions = predictions.cpu().numpy()
#     labels = labels.cpu().numpy()

#     # Handle different output formats
#     if isinstance(predictions, tuple):
#         predictions = predictions[0]

#     # Convert logits to predicted token IDs if necessary
#     if predictions.ndim == 3:
#         predicted_ids = np.argmax(predictions, axis=-1)
#     else:
#         predicted_ids = predictions

#     # Replace -100 in labels with pad_token_id
#     labels = np.where(labels != -100, labels, tokenizer.pad_token_id)

#     # Decode predictions and labels
#     decoded_predictions = tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)
#     decoded_references = tokenizer.batch_decode(labels, skip_special_tokens=True)

#     # Clean up decoded texts
#     decoded_predictions = [pred.strip() for pred in decoded_predictions]
#     decoded_references = [ref.strip() for ref in decoded_references]

#     # Prepare references for BLEU
#     formatted_references = [[ref] for ref in decoded_references]

#     # Compute metrics
#     bleu_results = bleu_metric.compute(predictions=decoded_predictions, references=formatted_references)
#     rouge_results = rouge_metric.compute(predictions=decoded_predictions, references=decoded_references)
#     bertscore_results = bertscore_metric.compute(predictions=decoded_predictions, references=decoded_references, lang="en")

#     # Log metrics to MLflow
#     mlflow.log_metric("bleu", bleu_results["bleu"])
#     for key, value in rouge_results.items():
#         mlflow.log_metric(f"rouge_{key}", value)
#     mlflow.log_metric("bertscore_precision", np.mean(bertscore_results["precision"]))
#     mlflow.log_metric("bertscore_recall", np.mean(bertscore_results["recall"]))
#     mlflow.log_metric("bertscore_f1", np.mean(bertscore_results["f1"]))

#     # Prepare metrics to return
#     metrics = {
#         "bleu": bleu_results["bleu"],
#         "bertscore_precision": np.mean(bertscore_results["precision"]),
#         "bertscore_recall": np.mean(bertscore_results["recall"]),
#         "bertscore_f1": np.mean(bertscore_results["f1"]),
#     }
#     metrics.update({f"rouge_{key}": value for key, value in rouge_results.items()})

#     return metrics

# %%
# import evaluate
# import numpy as np
# import torch
# import mlflow

# # Initialize evaluation metrics
# bleu_metric = evaluate.load("bleu")
# rouge_metric = evaluate.load("rouge")
# bertscore_metric = evaluate.load("bertscore")

# def print_gpu_usage(stage):
#     allocated = torch.cuda.memory_allocated()
#     reserved = torch.cuda.memory_reserved()
#     print(f"{stage} - Allocated Memory: {allocated / (1024 ** 2):.2f} MB, Reserved Memory: {reserved / (1024 ** 2):.2f} MB")

# def compute_metrics(eval_preds):
#     predictions, labels = eval_preds
    

#     # Print GPU usage before processing
#     print_gpu_usage("Before processing")

#     # Handle different output formats
#     if isinstance(predictions, tuple):
#         predictions = predictions[0]

#     # Convert logits to predicted token IDs if necessary
#     if predictions.ndim == 3:
#         predicted_ids = np.argmax(predictions, axis=-1)
#     else:
#         predicted_ids = predictions

#     # Replace -100 in labels with pad_token_id
#     labels = np.where(labels != -100, labels, tokenizer.pad_token_id)

#     # Decode predictions and labels
#     decoded_predictions = tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)
#     decoded_references = tokenizer.batch_decode(labels, skip_special_tokens=True)

#     # Clean up decoded texts
#     decoded_predictions = [pred.strip() for pred in decoded_predictions]
#     decoded_references = [ref.strip() for ref in decoded_references]

#     # Prepare references for BLEU
#     formatted_references = [[ref] for ref in decoded_references]

#     # Compute BLEU metric
#     print_gpu_usage("Before BLEU calculation")
#     bleu_results = bleu_metric.compute(predictions=decoded_predictions, references=formatted_references)
#     print_gpu_usage("After BLEU calculation")

#     # Compute ROUGE metric
#     print_gpu_usage("Before ROUGE calculation")
#     rouge_results = rouge_metric.compute(predictions=decoded_predictions, references=decoded_references)
#     print_gpu_usage("After ROUGE calculation")

#     # Compute BERTScore metric
#     print_gpu_usage("Before BERTScore calculation")
#     bertscore_results = bertscore_metric.compute(predictions=decoded_predictions, references=decoded_references, lang="en")
#     print_gpu_usage("After BERTScore calculation")

#     # Log metrics to MLflow
#     mlflow.log_metric("bleu", bleu_results["bleu"])
#     for key, value in rouge_results.items():
#         mlflow.log_metric(f"rouge_{key}", value)
#     mlflow.log_metric("bertscore_precision", np.mean(bertscore_results["precision"]))
#     mlflow.log_metric("bertscore_recall", np.mean(bertscore_results["recall"]))
#     mlflow.log_metric("bertscore_f1", np.mean(bertscore_results["f1"]))

#     # Prepare metrics to return
#     metrics = {
#         "bleu": bleu_results["bleu"],
#         "bertscore_precision": np.mean(bertscore_results["precision"]),
#         "bertscore_recall": np.mean(bertscore_results["recall"]),
#         "bertscore_f1": np.mean(bertscore_results["f1"]),
#     }
#     metrics.update({f"rouge_{key}": value for key, value in rouge_results.items()})

#     return metrics

# %%
import numpy as np
def inspect_logits(eval_preds):
    predictions, labels = eval_preds

    if isinstance(predictions, tuple):
        predictions = predictions[0]  # Extract logits if predictions is a tuple
        print("isinstance(predictions, tuple)")

    if predictions.ndim == 3:  # This means logits are of shape (batch_size, seq_length, vocab_size)
        print("Inspecting logits for the first few validation samples:")
        for i in range(min(2, predictions.shape[0])):  # Loop over the first two samples in the batch
            logits = predictions[i]
            print(f"Logits for validation sample {i}:")
            print(logits)  # Logits have shape (seq_length, vocab_size)

            max_logits = np.max(logits, axis=-1)  # Find the maximum logits across the vocab axis
            print(f"Maximum logits along sequence positions for sample {i}: {max_logits}")

            # Check if the logits are very low or mostly the same
            if np.allclose(max_logits, 0, atol=1e-3):
                print(f"All logits for sample {i} are close to zero.")
            elif np.allclose(max_logits, max_logits[0]):
                print(f"All logits for sample {i} are approximately the same, which may indicate an issue.")

# %%
def inspect_predictions(predictions):
    # Convert logits to token IDs if necessary
    if isinstance(predictions, tuple):
        predictions = predictions[0]
    
    if predictions.ndim == 3:  # Convert logits to predicted token IDs
        predicted_ids = np.argmax(predictions, axis=-1)
    else:
        predicted_ids = predictions

    # Print predicted token IDs for the first few validation samples
    print("Inspecting predicted token IDs for the first few validation samples:")
    for i in range(min(2, len(predicted_ids))):
        print(f"Predicted token IDs for sample {i}: {predicted_ids[i]}")

        # Check if the prediction is empty (i.e., all tokens are pad tokens)
        if np.all(predicted_ids[i] == tokenizer.pad_token_id):
            print(f"Prediction {i} contains only pad tokens, indicating an empty prediction.")

# %%
import evaluate
import numpy as np
import torch
import mlflow

# Initialize evaluation metrics
bleu_metric = evaluate.load("bleu")
rouge_metric = evaluate.load("rouge")
bertscore_metric = evaluate.load("bertscore")

def compute_metrics(eval_preds):
    print("in compute_metrics")
#     inspect_logits(eval_preds)
    predictions, labels = eval_preds
#     inspect_predictions(predictions)
    # Handle different output formats
    if isinstance(predictions, tuple):
        predictions = predictions[0]

    # Convert logits to predicted token IDs if necessary
    if predictions.ndim == 3:
        predicted_ids = np.argmax(predictions, axis=-1)
    else:
        predicted_ids = predictions

    # Replace -100 in labels with pad_token_id
    if tokenizer.pad_token_id is None:
        raise ValueError("Tokenizer pad_token_id is not set. Please ensure tokenizer.pad_token_id is defined.")
    
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)

    # Decode predictions and labels
    decoded_predictions = tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)
    decoded_references = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Clean up decoded texts
    decoded_predictions = [pred.strip() for pred in decoded_predictions]
    decoded_references = [ref.strip() for ref in decoded_references]

    # Enhanced check for empty predictions or references
    empty_predictions_indices = [i for i, pred in enumerate(decoded_predictions) if not pred]
    empty_references_indices = [i for i, ref in enumerate(decoded_references) if not ref]

    if empty_predictions_indices or empty_references_indices:
        print("Warning: Empty predictions or references found.")
        if empty_predictions_indices:
            print(f"Empty predictions at indices: {empty_predictions_indices}")
        if empty_references_indices:
            print(f"Empty references at indices: {empty_references_indices}")
        # Optionally, you can handle this case differently instead of raising an error
        # For example, setting empty predictions/references to a default value like "[EMPTY]"
        # decoded_predictions = ["[EMPTY]" if i in empty_predictions_indices else pred for i, pred in enumerate(decoded_predictions)]
        # decoded_references = ["[EMPTY]" if i in empty_references_indices else ref for i, ref in enumerate(decoded_references)]
#         for i in range(len(decoded_predictions)):
#             print(f"prediction at index {i}: Original text = {decoded_predictions[i]}")
        for i in range(len(decoded_predictions)):
            print(f"reference at index {i}: Original text = {decoded_references[i]}")

    # Prepare references for BLEU
    formatted_references = [[ref] for ref in decoded_references]

    # Compute BLEU metric
    bleu_results = bleu_metric.compute(predictions=decoded_predictions, references=formatted_references)

    # Compute ROUGE metric
    rouge_results = rouge_metric.compute(predictions=decoded_predictions, references=decoded_references)

    if all(decoded_predictions) and all(decoded_references):
        bertscore_results = bertscore_metric.compute(predictions=decoded_predictions, references=decoded_references, lang="en")
    else:
        print("Skipping BERTScore due to empty predictions or references.")
        bertscore_results = {"precision": [0], "recall": [0], "f1": [0]}


    # Log metrics to MLflow
    try:
        mlflow.log_metric("bleu", bleu_results["bleu"])
        for key, value in rouge_results.items():
            mlflow.log_metric(f"rouge_{key}", value)
        mlflow.log_metric("bertscore_precision", np.mean(bertscore_results["precision"]))
        mlflow.log_metric("bertscore_recall", np.mean(bertscore_results["recall"]))
        mlflow.log_metric("bertscore_f1", np.mean(bertscore_results["f1"]))
    except Exception as e:
        print(f"Error logging metrics to MLflow: {e}")

    # Prepare metrics to return
    metrics = {
        "bleu": bleu_results["bleu"],
        "bertscore_precision": np.mean(bertscore_results["precision"]),
        "bertscore_recall": np.mean(bertscore_results["recall"]),
        "bertscore_f1": np.mean(bertscore_results["f1"]),
    }
    metrics.update({f"rouge_{key}": value for key, value in rouge_results.items()})

    return metrics
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
# from transformers import DataCollatorForLanguageModeling

# class DataCollatorWithPaddingAndMasking(DataCollatorForLanguageModeling):
#     def __call__(self, examples):
#         print("type example", type(examples))
#         print("len examples",len(examples))
#         print("example", examples)
#         batch = tokenizer(
#             [example['text'] for example in examples],
#             padding=True,
#             truncation=True,
#             max_length=max_seq_length,
#             return_tensors='pt',
#         )

#         # Create labels tensor
#         labels = batch['input_ids'].clone()

#         # Identify the prompt and response tokens
#         for i, example in enumerate(examples):
#             prompt_end = example['text'].find('Response:')
#             prompt_tokens = tokenizer(
#                 example['text'][:prompt_end],
#                 truncation=True,
#                 max_length=max_seq_length,
#             )['input_ids']
#             num_prompt_tokens = len(prompt_tokens)

#             # Mask prompt tokens in labels
#             labels[i, :num_prompt_tokens] = -100

#         batch['labels'] = labels
#         return batch

# %%
# data_collator = DataCollatorWithPaddingAndMasking(
#     tokenizer=tokenizer,
#     mlm=False,  # We're doing causal language modeling
# )

# %%
import subprocess
from transformers import TrainerCallback
class SaveAllCheckpointsCallback(TrainerCallback):
    def __init__(self, save_dir, save_steps=50):
        self.save_dir = save_dir
        self.save_steps = save_steps
#     def on_evaluate(self, args, state, control, **kwargs):
#         print("on_evaluate")
#         print("kwargs in on_evaluate\n", kwargs)
#         logits = kwargs['metrics']['eval_logits']
#         # Log the first logits tensor
#         print(f"Logits for the first sample: {logits[0]}")
    def on_step_end(self, args, state, control, **kwargs):
        print("step ", state.global_step)
        for name, param in kwargs['model'].named_parameters():
            print(f"param Name {name} {param.requires_grad} {param.grad==None}")
            if param.grad is not None:
                max_grad = param.grad.abs().max().item()
                print(f"Max gradient for {name} at step {state.global_step}: {max_grad}")

    def on_save(self, args, state, control, **kwargs):
        if state.global_step % self.save_steps == 0:
            self._save_full_checkpoint(state.global_step)

    def _save_full_checkpoint(self, step):
        # Create checkpoint directory
        checkpoint_dir = os.path.join(self.save_dir, f"checkpoint-{step}")
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        # Save checkpoint using DVC
        try:
            result = subprocess.run(['dvc', 'add', checkpoint_dir], capture_output=True, text=True)
            if result.returncode == 0:
                print(f"Successfully added {checkpoint_dir} to DVC.")
            else:
                print(f"Error adding {checkpoint_dir} to DVC: {result.stderr}")
                subprocess.run(["dvc", "push"], check=True, cwd='.')
                print(f"Full training checkpoint saved and pushed to DagsHub: {checkpoint_dir}")
        except Exception as e:
            print(f"Failed to save checkpoint: {e}")

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
# val_dataset_df = val_dataset.remove_columns(['split', 'type', 'instruction', 'input', 'context']).to_pandas()

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

training_args = TrainingArguments(
        per_device_train_batch_size = 4,#2,
        per_device_eval_batch_size = 2,
#         use_cpu = True,
        eval_accumulation_steps = 2,
#         eval_delay = 5,
        gradient_accumulation_steps = 8,#4,
        warmup_steps = 191,
        eval_strategy ='steps',
        max_grad_norm=1.0,
        eval_steps=3,
        save_steps=3,
        save_strategy='steps',
        save_total_limit=3,
#         max_steps = 60,
        num_train_epochs = 1,
        learning_rate = 1e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 3,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine_with_restarts",#"linear",
        seed = 3407,
        output_dir = "outputs",
#         remove_unused_columns=False,
        report_to= 'mlflow',#'all'#"wandb"
    )
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    eval_dataset = val_dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    compute_metrics = compute_metrics,
#     data_collator = data_collator,
#     callbacks = [MlflowEvaluationCallback(val_dataset_df, tokenizer,15)],
    packing = False, # Can make training 5x faster for short sequences. 
    args = training_args
)

# %%
trainer.add_callback(SaveAllCheckpointsCallback(save_dir=training_args.output_dir,save_steps = training_args.save_steps ))

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla P100-PCIE-16GB. Max memory = 15.888 GB.
# 3.826 GB of memory reserved.

# %%
# Start training within an MLflow run
with mlflow.start_run():
    trainer_stats = trainer.train()
# Out:
# **** Unsloth: Please use our fixed gradient_accumulation_steps by updating transformers and Unsloth!
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 61,245 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 8
# \        /    Total batch size = 32 | Total steps = 1,914
#  "-____-"     Number of trainable parameters = 39,976,960
#     <div>
#
#       <progress value='31' max='1914' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  31/1914 1:00:06 < 65:03:06, 0.01 it/s, Epoch 0.02/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Bertscore Precision</th>
#       <th>Bertscore Recall</th>
#       <th>Bertscore F1</th>
#       <th>Rouge Rouge1</th>
#       <th>Rouge Rouge2</th>
#       <th>Rouge Rougel</th>
#       <th>Rouge Rougelsum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>11.627000</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>16.732800</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>12.023800</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.983300</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>148.077900</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>6.604400</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>6.416800</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>5.693900</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>15.587500</td>
#       <td>nan</td>
#       <td>0.116425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.282496</td>
#       <td>0.129038</td>
#       <td>0.237803</td>
#       <td>0.250929</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='23' max='45' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23/45 00:47 < 00:47, 0.46 it/s]
#     </div>
# step  1
# param Name base_model.model.model.embed_tokens.weight False True
# param Name base_model.model.model.layers.0.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.0.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.0.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.0.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.0.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.0.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.0.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.0.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.0.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.0.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.0.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.0.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.0.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.0.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.0.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.0.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.0.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.0.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.0.input_layernorm.weight False True
# param Name base_model.model.model.layers.0.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.1.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.1.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.1.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.1.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.1.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.1.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.1.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.1.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.1.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.1.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.1.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.1.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.1.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.1.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.1.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.1.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.1.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.1.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.1.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.1.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.1.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.1.input_layernorm.weight False True
# param Name base_model.model.model.layers.1.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.2.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.2.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.2.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.2.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.2.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.2.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.2.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.2.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.2.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.2.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.2.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.2.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.2.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.2.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.2.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.2.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.2.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.2.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.2.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.2.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.2.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.2.input_layernorm.weight False True
# param Name base_model.model.model.layers.2.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.3.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.3.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.3.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.3.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.3.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.3.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.3.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.3.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.3.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.3.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.3.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.3.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.3.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.3.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.3.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.3.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.3.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.3.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.3.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.3.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.3.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.3.input_layernorm.weight False True
# param Name base_model.model.model.layers.3.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.4.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.4.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.4.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.4.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.4.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.4.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.4.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.4.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.4.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.4.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.4.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.4.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.4.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.4.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.4.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.4.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.4.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.4.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.4.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.4.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.4.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.4.input_layernorm.weight False True
# param Name base_model.model.model.layers.4.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.5.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.5.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.5.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.5.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.5.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.5.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.5.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.5.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.5.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.5.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.5.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.5.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.5.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.5.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.5.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.5.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.5.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.5.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.5.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.5.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.5.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.5.input_layernorm.weight False True
# param Name base_model.model.model.layers.5.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.6.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.6.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.6.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.6.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.6.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.6.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.6.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.6.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.6.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.6.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.6.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.6.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.6.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.6.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.6.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.6.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.6.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.6.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.6.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.6.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.6.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.6.input_layernorm.weight False True
# param Name base_model.model.model.layers.6.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.7.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.7.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.7.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.7.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.7.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.7.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.7.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.7.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.7.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.7.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.7.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.7.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.7.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.7.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.7.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.7.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.7.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.7.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.7.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.7.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.7.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.7.input_layernorm.weight False True
# param Name base_model.model.model.layers.7.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.8.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.8.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.8.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.8.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.8.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.8.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.8.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.8.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.8.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.8.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.8.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.8.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.8.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.8.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.8.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.8.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.8.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.8.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.8.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.8.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.8.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.8.input_layernorm.weight False True
# param Name base_model.model.model.layers.8.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.9.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.9.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.9.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.9.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.9.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.9.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.9.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.9.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.9.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.9.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.9.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.9.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.9.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.9.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.9.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.9.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.9.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.9.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.9.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.9.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.9.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.9.input_layernorm.weight False True
# param Name base_model.model.model.layers.9.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.10.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.10.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.10.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.10.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.10.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.10.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.10.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.10.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.10.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.10.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.10.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.10.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.10.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.10.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.10.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.10.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.10.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.10.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.10.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.10.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.10.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.10.input_layernorm.weight False True
# param Name base_model.model.model.layers.10.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.11.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.11.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.11.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.11.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.11.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.11.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.11.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.11.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.11.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.11.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.11.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.11.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.11.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.11.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.11.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.11.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.11.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.11.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.11.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.11.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.11.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.11.input_layernorm.weight False True
# param Name base_model.model.model.layers.11.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.12.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.12.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.12.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.12.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.12.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.12.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.12.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.12.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.12.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.12.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.12.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.12.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.12.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.12.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.12.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.12.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.12.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.12.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.12.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.12.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.12.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.12.input_layernorm.weight False True
# param Name base_model.model.model.layers.12.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.13.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.13.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.13.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.13.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.13.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.13.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.13.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.13.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.13.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.13.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.13.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.13.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.13.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.13.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.13.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.13.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.13.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.13.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.13.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.13.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.13.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.13.input_layernorm.weight False True
# param Name base_model.model.model.layers.13.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.14.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.14.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.14.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.14.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.14.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.14.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.14.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.14.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.14.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.14.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.14.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.14.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.14.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.14.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.14.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.14.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.14.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.14.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.14.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.14.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.14.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.14.input_layernorm.weight False True
# param Name base_model.model.model.layers.14.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.15.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.15.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.15.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.15.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.15.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.15.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.15.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.15.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.15.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.15.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.15.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.15.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.15.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.15.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.15.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.15.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.15.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.15.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.15.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.15.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.15.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.15.input_layernorm.weight False True
# param Name base_model.model.model.layers.15.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.16.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.16.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.16.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.16.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.16.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.16.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.16.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.16.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.16.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.16.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.16.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.16.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.16.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.16.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.16.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.16.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.16.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.16.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.16.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.16.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.16.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.16.input_layernorm.weight False True
# param Name base_model.model.model.layers.16.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.17.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.17.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.17.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.17.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.17.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.17.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.17.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.17.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.17.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.17.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.17.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.17.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.17.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.17.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.17.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.17.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.17.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.17.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.17.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.17.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.17.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.17.input_layernorm.weight False True
# param Name base_model.model.model.layers.17.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.18.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.18.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.18.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.18.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.18.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.18.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.18.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.18.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.18.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.18.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.18.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.18.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.18.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.18.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.18.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.18.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.18.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.18.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.18.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.18.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.18.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.18.input_layernorm.weight False True
# param Name base_model.model.model.layers.18.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.19.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.19.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.19.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.19.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.19.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.19.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.19.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.19.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.19.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.19.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.19.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.19.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.19.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.19.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.19.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.19.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.19.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.19.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.19.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.19.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.19.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.19.input_layernorm.weight False True
# param Name base_model.model.model.layers.19.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.20.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.20.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.20.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.20.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.20.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.20.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.20.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.20.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.20.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.20.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.20.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.20.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.20.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.20.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.20.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.20.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.20.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.20.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.20.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.20.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.20.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.20.input_layernorm.weight False True
# param Name base_model.model.model.layers.20.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.21.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.21.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.21.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.21.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.21.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.21.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.21.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.21.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.21.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.21.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.21.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.21.self_attn.o_proj.lora_B.default.weight True True
# ...
# param Name base_model.model.model.layers.24.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.24.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.24.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.24.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.24.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.24.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.24.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.24.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.24.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.24.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.24.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.24.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.24.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.24.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.24.input_layernorm.weight False True
# param Name base_model.model.model.layers.24.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.25.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.25.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.25.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.25.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.25.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.25.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.25.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.25.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.25.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.25.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.25.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.25.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.25.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.25.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.25.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.25.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.25.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.25.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.25.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.25.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.25.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.25.input_layernorm.weight False True
# param Name base_model.model.model.layers.25.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.26.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.26.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.26.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.26.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.26.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.26.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.26.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.26.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.26.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.26.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.26.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.26.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.26.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.26.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.26.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.26.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.26.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.26.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.26.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.26.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.26.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.26.input_layernorm.weight False True
# param Name base_model.model.model.layers.26.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.27.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.27.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.27.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.27.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.27.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.27.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.27.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.27.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.27.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.27.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.27.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.27.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.27.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.27.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.27.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.27.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.27.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.27.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.27.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.27.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.27.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.27.input_layernorm.weight False True
# param Name base_model.model.model.layers.27.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.28.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.28.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.28.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.28.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.28.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.28.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.28.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.28.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.28.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.28.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.28.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.28.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.28.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.28.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.28.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.28.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.28.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.28.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.28.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.28.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.28.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.28.input_layernorm.weight False True
# param Name base_model.model.model.layers.28.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.29.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.29.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.29.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.29.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.29.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.29.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.29.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.29.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.29.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.29.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.29.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.29.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.29.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.29.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.29.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.29.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.29.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.29.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.29.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.29.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.29.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.29.input_layernorm.weight False True
# param Name base_model.model.model.layers.29.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.30.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.30.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.30.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.30.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.30.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.30.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.30.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.30.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.30.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.30.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.30.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.30.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.30.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.30.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.30.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.30.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.30.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.30.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.30.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.30.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.30.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.30.input_layernorm.weight False True
# param Name base_model.model.model.layers.30.post_attention_layernorm.weight False True
# param Name base_model.model.model.layers.31.self_attn.q_proj.base_layer.weight False True
# param Name base_model.model.model.layers.31.self_attn.q_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.31.self_attn.q_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.31.self_attn.k_proj.base_layer.weight False True
# param Name base_model.model.model.layers.31.self_attn.k_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.31.self_attn.k_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.31.self_attn.v_proj.base_layer.weight False True
# param Name base_model.model.model.layers.31.self_attn.v_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.31.self_attn.v_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.31.self_attn.o_proj.base_layer.weight False True
# param Name base_model.model.model.layers.31.self_attn.o_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.31.self_attn.o_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.31.mlp.gate_proj.base_layer.weight False True
# param Name base_model.model.model.layers.31.mlp.gate_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.31.mlp.gate_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.31.mlp.up_proj.base_layer.weight False True
# param Name base_model.model.model.layers.31.mlp.up_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.31.mlp.up_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.31.mlp.down_proj.base_layer.weight False True
# param Name base_model.model.model.layers.31.mlp.down_proj.lora_A.default.weight True True
# param Name base_model.model.model.layers.31.mlp.down_proj.lora_B.default.weight True True
# param Name base_model.model.model.layers.31.input_layernorm.weight False True
# param Name base_model.model.model.layers.31.post_attention_layernorm.weight False True
# param Name base_model.model.model.norm.weight False True
# param Name base_model.model.lm_head.weight False True

# %%
import os
import torch
import mlflow
import dvc.api
from dvc.repo import Repo
from transformers import Trainer, TrainingArguments
from pathlib import Path

# Assuming your model is a PyTorch model
class CheckpointManager:
    def __init__(self, checkpoint_dir="checkpoints"):
        self.checkpoint_dir = checkpoint_dir
        os.makedirs(self.checkpoint_dir, exist_ok=True)

    def save_checkpoint(self, model, optimizer, epoch):
        # Save the model state and optimizer state
        checkpoint_path = os.path.join(self.checkpoint_dir, f"checkpoint_epoch_{epoch}.pt")
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
        }, checkpoint_path)
        print(f"Checkpoint saved at {checkpoint_path}")
        
        # Log to MLflow
        mlflow.log_artifact(checkpoint_path, artifact_path="checkpoints")

    def load_checkpoint(self, model, optimizer, checkpoint_path):
        # Load the checkpoint to resume training
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        print(f"Loaded checkpoint from {checkpoint_path}")
        return checkpoint['epoch']



# Initialize CheckpointManager
checkpoint_manager = CheckpointManager()

# Example TrainingArguments for HuggingFace Trainer
training_args = TrainingArguments(
    output_dir="outputs",
    per_device_train_batch_size=4,
    logging_steps=10,
    save_steps=50,  # Save checkpoints every 50 steps
    save_total_limit=3,  # Keep only the last 3 checkpoints
    load_best_model_at_end=True
)



# Start MLflow run
with mlflow.start_run() as run:
    for epoch in range(num_epochs):
        # Training loop - update model
        trainer.train()

        # Save checkpoint after each epoch
        checkpoint_manager.save_checkpoint(trainer.model, trainer.optimizer, epoch)

        # Use DVC API to add and push checkpoints to remote
        repo = Repo(".")
        repo.add("checkpoints")
        repo.push(remote="origin")

        # Log checkpoints to DagsHub via MLflow
        mlflow.log_artifact(checkpoint_manager.checkpoint_dir, artifact_path="checkpoints")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 42
#      39 checkpoint_manager = CheckpointManager()
#      41 # Example TrainingArguments for HuggingFace Trainer
# ---> 42 training_args = TrainingArguments(
#      43     output_dir="outputs",
#      44     per_device_train_batch_size=4,
#      45     logging_steps=10,
#      46     save_steps=50,  # Save checkpoints every 50 steps
#      47     save_total_limit=3,  # Keep only the last 3 checkpoints
#      48     load_best_model_at_end=True
#      49 )
#      53 # Start MLflow run
#      54 with mlflow.start_run() as run:
#
# File <string>:131, in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, eval_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, torch_empty_cache_steps, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, lr_scheduler_kwargs, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, restore_callback_states_from_checkpoint, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, dataloader_prefetch_factor, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, accelerator_config, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, ddp_broadcast_buffers, dataloader_pin_memory, dataloader_persistent_workers, skip_memory_metrics, use_legacy_prediction_loop, push_to_hub, resume_from_checkpoint, hub_model_id, hub_strategy, hub_token, hub_private_repo, hub_always_push, gradient_checkpointing, gradient_checkpointing_kwargs, include_inputs_for_metrics, eval_do_concat_batches, fp16_backend, evaluation_strategy, push_to_hub_model_id, push_to_hub_organization, push_to_hub_token, mp_parameters, auto_find_batch_size, full_determinism, torchdynamo, ray_scope, ddp_timeout, torch_compile, torch_compile_backend, torch_compile_mode, dispatch_batches, split_batches, include_tokens_per_second, include_num_input_tokens_seen, neftune_noise_alpha, optim_target_modules, batch_eval_metrics, eval_on_start, eval_use_gather_object)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1593, in TrainingArguments.__post_init__(self)
#    1591 if self.load_best_model_at_end:
#    1592     if self.eval_strategy != self.save_strategy:
# -> 1593         raise ValueError(
#    1594             "--load_best_model_at_end requires the save and eval strategy to match, but found\n- Evaluation "
#    1595             f"strategy: {self.eval_strategy}\n- Save strategy: {self.save_strategy}"
#    1596         )
#    1597     if self.eval_strategy == IntervalStrategy.STEPS and self.save_steps % self.eval_steps != 0:
#    1598         if self.eval_steps < 1 or self.save_steps < 1:
#
# ValueError: --load_best_model_at_end requires the save and eval strategy to match, but found
# - Evaluation strategy: no
# - Save strategy: steps

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #@title Show final memory and time stats
# ----> 2 used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
#       3 used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
#       4 used_percentage = round(used_memory         /max_memory*100, 3)
#
# NameError: name 'torch' is not defined

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
# prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    prompt.format(
        "Continue the fibonnaci sequence.", # instruction
        "1, 1, 2, 3, 5, 8", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
tokenizer.batch_decode(outputs)

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
# prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    prompt.format(
        "Continue the fibonnaci sequence.", # instruction
        "1, 1, 2, 3, 5, 8", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set") # Local saving
model.push_to_hub("niloufarna/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", token = "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") # Online saving

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if True:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# prompt = You MUST copy from above!

inputs = tokenizer(
[
    prompt.format(
        "What is a famous tall tower in Paris?", # instruction
        "", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 64)

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if True: model.save_pretrained_merged("model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, save_method = "merged_16bit",)
if True: model.push_to_hub_merged("niloufarna/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set_16bit", tokenizer, save_method = "merged_16bit", token = "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")

# Merge to 4bit
if False: model.save_pretrained_merged("model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, save_method = "merged_4bit", token = "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")

# Just LoRA adapters
if False: model.save_pretrained_merged("model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, save_method = "lora", token = "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")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer,)
if False: model.push_to_hub_gguf("hf/model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set", tokenizer, quantization_method = "q4_k_m", token = "")

# %%
model.push_to_hub("ashishpatel26/Llama2_Finetuned_Articles_Constitution_3300_Instruction_Set",create_pr=1)

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Mistral 7b 2x faster [free Colab](https://colab.research.google.com/drive/1Dyauq4kTZoLewQ1cApceUQVNcnnNTzg_?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
# 9. Gemma 6 trillion tokens is 2.5x faster! [free Colab](https://colab.research.google.com/drive/10NbwlsRChbma1v55m8LAPYG15uQv6HLo?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
